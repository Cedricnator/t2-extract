# %%
import pandas as pd

df = pd.read_csv('../../data/top_repositories.csv')

df_cleaned = df.dropna()
df_cleaned
# Out:
#               id                name                        full_name  \
# 0       70081338  vuejs-2-na-pratica  Webschool-io/vuejs-2-na-pratica
# 1      157641299             vue-ref             vueComponent/vue-ref
# 2      202672512          vue-h5-pro              now1then/vue-h5-pro
# 3       11218168           ray-march              lightbits/ray-march
# 4       62526871               speck                       scup/speck
# ...          ...                 ...                              ...
# 22800  295016801         go-diagrams              blushft/go-diagrams
# 22801  235685125                deej                   omriharel/deej
# 22802  173582015             octosql                 cube2222/octosql
# 22803     756967              gocode                       nsf/gocode
# 22804  171396748              cubefs                    cubefs/cubefs
#
#               owner                                           html_url  \
# 0      Webschool-io  https://github.com/Webschool-io/vuejs-2-na-pra...
# 1      vueComponent            https://github.com/vueComponent/vue-ref
# 2          now1then             https://github.com/now1then/vue-h5-pro
# 3         lightbits             https://github.com/lightbits/ray-march
# 4              scup                      https://github.com/scup/speck
# ...             ...                                                ...
# 22800       blushft             https://github.com/blushft/go-diagrams
# 22801     omriharel                  https://github.com/omriharel/deej
# 22802      cube2222                https://github.com/cube2222/octosql
# 22803           nsf                      https://github.com/nsf/gocode
# 22804        cubefs                   https://github.com/cubefs/cubefs
#
#                                              description  \
# 0        Curso totalmente prático de Vue.js da Webschool
# 1      You can use the callback to get a reference li...
# 2                              🚀 基于@vue/CLI3构建的移动端h5项目模板
# 3      Rendering procedural 3D geometry by raymarchin...
# 4               Domain entities with reactive validation
# ...                                                  ...
# 22800           Create beautiful system diagrams with Go
# 22801  Set app volumes with real sliders! deej is an ...
# 22802  OctoSQL is a query tool that allows you to joi...
# 22803  An autocompletion daemon for the Go programmin...
# 22804                   cloud-native distributed storage
#
#                  created_at            updated_at    language  \
# 0      2016-10-05T17:09:50Z  2022-05-27T13:21:11Z  JavaScript
# 1      2018-11-15T02:36:37Z  2023-06-12T06:05:15Z  JavaScript
# 2      2019-08-16T06:37:12Z  2023-10-26T11:46:18Z  JavaScript
# 3      2013-07-06T12:51:27Z  2024-07-18T13:14:39Z  JavaScript
# 4      2016-07-04T02:50:04Z  2024-01-15T10:00:04Z  JavaScript
# ...                     ...                   ...         ...
# 22800  2020-09-12T19:59:52Z  2025-04-10T22:57:29Z          Go
# 22801  2020-01-22T23:03:46Z  2025-04-10T12:37:54Z          Go
# 22802  2019-03-03T13:59:25Z  2025-04-08T23:15:14Z          Go
# 22803  2010-07-05T00:13:16Z  2025-04-11T01:44:34Z          Go
# 22804  2019-02-19T03:15:04Z  2025-04-11T06:47:49Z          Go
#
#        stargazers_count  forks_count  open_issues_count  watchers
# 0                   100           34                  2       100
# 1                   100           14                  5       100
# 2                   100           48                 20       100
# 3                   100           16                  0       100
# 4                   100            8                  5       100
# ...                 ...          ...                ...       ...
# 22800              5036          223                 17      5036
# 22801              5033          491                 33      5033
# 22802              5019          206                 50      5019
# 22803              5009          659                 66      5009
# 22804              5007          656                246      5007
#
# [22112 rows x 13 columns]

# %%
print(f"Total de repositorios: {len(df_cleaned)}")

df_cleaned.describe()
# Out:
# Total de repositorios: 22112
#                  id  stargazers_count   forks_count  open_issues_count  \
# count  2.211200e+04      22112.000000  22112.000000       22112.000000
# mean   2.115075e+08       3490.049295    556.097368          82.372467
# std    2.283509e+08       8533.451916   1799.570015         345.998719
# min    1.904000e+03         87.000000      0.000000           0.000000
# 25%    4.039537e+07        431.000000     39.000000           5.000000
# 50%    1.196597e+08        872.500000    121.000000          18.000000
# 75%    3.079477e+08       3554.250000    432.000000          60.000000
# max    9.592125e+08     296001.000000  79080.000000       26645.000000
#
#             watchers
# count   22112.000000
# mean     3490.049295
# std      8533.451916
# min        87.000000
# 25%       431.000000
# 50%       872.500000
# 75%      3554.250000
# max    296001.000000

# %%
import matplotlib.pyplot as plt
import seaborn as sns

language_counts = df_cleaned['language'].value_counts().head(5)
plt.figure(figsize=(12, 9))
sns.barplot(x=language_counts.index, y=language_counts.values)
plt.title('Top 5 de Lenguajes de Programacion en Repositorios Populares')
plt.xlabel('Numero de repositorios')
plt.ylabel('Lenguaje de Programacion')
plt.tight_layout()
plt.show()

# %%
# Convertir columnas de fechas a datetime
df_cleaned['created_at'] = pd.to_datetime(df_cleaned['created_at'])
df_cleaned['updated_at'] = pd.to_datetime(df_cleaned['updated_at'])

# Extraer año de creación
df_cleaned['created_year'] = df_cleaned['created_at'].dt.year

# Contar por año
year_counts = df_cleaned['created_year'].value_counts().sort_index()

# Visualización
plt.figure(figsize=(14, 8))
sns.lineplot(x=year_counts.index, y=year_counts.values)
plt.title('Número de Repositorios Populares Creados por Año')
plt.xlabel('Año')
plt.ylabel('Número de Repositorios')
plt.grid(True, alpha=0.3)
plt.show()
# Out:
# /tmp/ipykernel_11938/1525820970.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cleaned['created_at'] = pd.to_datetime(df_cleaned['created_at'])
# /tmp/ipykernel_11938/1525820970.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cleaned['updated_at'] = pd.to_datetime(df_cleaned['updated_at'])
# /tmp/ipykernel_11938/1525820970.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cleaned['created_year'] = df_cleaned['created_at'].dt.year

# %%
# Variables numéricas para correlación
numeric_cols = ['stargazers_count', 'watchers', 'forks_count', 'open_issues_count']

# Matriz de correlación
corr_matrix = df_cleaned[numeric_cols].corr()

# Visualización
plt.figure(figsize=(10, 8))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', vmin=-1, vmax=1)
plt.title('Correlación entre Métricas de Repositorios')
plt.tight_layout()
plt.show()

# %%
# Top 20 repositorios más populares
top_repos = df_cleaned.sort_values('stargazers_count', ascending=False).head(20)

plt.figure(figsize=(14, 10))
sns.barplot(x='stargazers_count', y='name', data=top_repos)
plt.title('Top 20 Repositorios por Número de Estrellas')
plt.xlabel('Número de Estrellas')
plt.ylabel('Nombre del Repositorio')
plt.tight_layout()
plt.show()

# %%
# Relación entre estrellas e issues
plt.figure(figsize=(12, 8))
sns.scatterplot(x='stargazers_count', y='open_issues_count', 
                hue='language', size='forks_count',
                sizes=(20, 200), alpha=0.7, data=df_cleaned)
plt.title('Estrellas vs. Issues Abiertas')
plt.xlabel('Número de Estrellas')
plt.ylabel('Número de Issues Abiertas')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# %%
# Agregar columna para ratio fork/estrella
df_cleaned['fork_star_ratio'] = df_cleaned['forks_count'] / df_cleaned['stargazers_count']

# Por lenguaje
lang_ratios = df_cleaned.groupby('language')['fork_star_ratio'].mean().sort_values(ascending=False).head(15)

plt.figure(figsize=(12, 8))
sns.barplot(x=lang_ratios.values, y=lang_ratios.index)
plt.title('Proporción Fork/Estrella por Lenguaje')
plt.xlabel('Ratio Fork/Estrella (promedio)')
plt.ylabel('Lenguaje')
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_11938/3552977927.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cleaned['fork_star_ratio'] = df_cleaned['forks_count'] / df_cleaned['stargazers_count']

# %%
# Add this cell to your notebook
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt

# Select features for clustering
features = ['stargazers_count', 'forks_count', 'open_issues_count', 'watchers']

# Get data and handle missing values
X = df_cleaned[features].fillna(0)

# Standardize the data
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Calculate WCSS (Within-Cluster Sum of Square) for different values of k
wcss = []
k_range = range(1, 11)

for k in k_range:
    kmeans = KMeans(n_clusters=k, random_state=42, n_init=10)
    kmeans.fit(X_scaled)
    wcss.append(kmeans.inertia_)

# Plot the Elbow Method graph
plt.figure(figsize=(12, 6))
plt.plot(k_range, wcss, marker='o', linestyle='-')
plt.xlabel('Number of Clusters')
plt.ylabel('WCSS (Within-Cluster Sum of Squares)')
plt.title('Elbow Method for Optimal Number of Clusters')
plt.grid(True, alpha=0.3)
plt.xticks(k_range)


plt.tight_layout()
plt.show()

# %%
# Crear un diccionario con todos los análisis para exportar a JSON
import json
import numpy as np

# Función auxiliar para manejar tipos no serializables por defecto en JSON
def json_serializable(obj):
   if isinstance(obj, (np.integer, np.int64)):
      return int(obj)
   elif isinstance(obj, np.floating):
      return float(obj)
   elif isinstance(obj, np.ndarray):
      return obj.tolist()
   elif isinstance(obj, pd.Timestamp):
      return obj.strftime('%Y-%m-%d')
   else:
      return str(obj)

# Estructura de datos para el frontend
frontend_data = {
   "summary": {
      "total_repositories": len(df_cleaned),
      "avg_stars": df_cleaned['stargazers_count'].mean(),
      "avg_forks": df_cleaned['forks_count'].mean(),
      "avg_issues": df_cleaned['open_issues_count'].mean(),
   },
    
   "languages": {
      "labels": language_counts.index.tolist(),
      "values": language_counts.values.tolist()
   },
   
   "yearly_creation": {
      "years": year_counts.index.tolist(),
      "counts": year_counts.values.tolist()
   },
   
   "correlations": {
      "metrics": numeric_cols,
      "matrix": corr_matrix.to_dict()
   },
   
   "top_repositories": top_repos[['name', 'full_name', 'html_url', 'stargazers_count', 'forks_count', 'language']].to_dict('records'),
   
   "fork_star_ratio": {
      "languages": lang_ratios.index.tolist(),
      "ratios": lang_ratios.values.tolist()
   }
}

# %%
from kneed import KneeLocator

# Find the elbow point automatically
knee = KneeLocator(list(k_range), wcss, curve="convex", direction="decreasing")
optimal_k_from_elbow = knee.elbow if knee.elbow else 3  # Fallback to 3 if no clear elbow

print(f"Automatically detected elbow point: k={optimal_k_from_elbow}")

# Apply K-means with optimal number of clusters (replace n with your chosen value)
optimal_k = 3  # Replace with the value you identify from the elbow plot
kmeans = KMeans(n_clusters=optimal_k, random_state=42, n_init=10)
df_cleaned['cluster'] = kmeans.fit_predict(X_scaled)

# Visualize clusters
plt.figure(figsize=(14, 10))
scatter = plt.scatter(
   df_cleaned['stargazers_count'], 
   df_cleaned['forks_count'],
   c=df_cleaned['cluster'], 
   cmap='viridis', 
   alpha=0.6, 
   s=100
)
plt.xscale('log')
plt.yscale('log')
plt.xlabel('Number of Stars (log scale)')
plt.ylabel('Number of Forks (log scale)')
plt.title('Repository Clusters')
plt.colorbar(scatter, label='Cluster')
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

# Analyze cluster characteristics
cluster_analysis = df_cleaned.groupby('cluster')[features].mean()
print("Cluster Centers:")
print(cluster_analysis)

# Add cluster info to your JSON export
frontend_data["clusters"] = {
   "count": optimal_k,
   "repositories_per_cluster": df_cleaned['cluster'].value_counts().to_dict(),
   "cluster_centers": cluster_analysis.to_dict()
}

# Format elbow method data for the frontend
frontend_data["elbow_method"] = {
    "optimal_k": int(optimal_k_from_elbow),
    "points": [{"k": int(k), "wcss": float(w)} for k, w in zip(k_range, wcss)]
}

# Guardar datos para el frontend
with open('../../data/github_analysis.json', 'w', encoding='utf-8') as f:
   json.dump(frontend_data, f, default=json_serializable, indent=2)

print("Datos exportados correctamente para el frontend")
# Out:
# Automatically detected elbow point: k=3
# /tmp/ipykernel_11938/1590311494.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cleaned['cluster'] = kmeans.fit_predict(X_scaled)
# Cluster Centers:
#          stargazers_count   forks_count  open_issues_count      watchers
# cluster
# 0             1997.422566    303.761050          51.894131   1997.422566
# 1            24541.856908   3755.619243         514.569901  24541.856908
# 2            96758.949153  23730.898305        1938.728814  96758.949153
# Datos exportados correctamente para el frontend
